# %%
import pandas as pd
#creating a dictionary of a series

d = {'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
     'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}
#creating a dataframe

df = pd.DataFrame(d)
print(df)
print('####### Sum ######')
print(df.sum())
print('###### Mean ######')
print(df.mean())
print('###### Standard Deviation ######')
print(df.std())
print('###### Descriptive Statistics ######')
print(df.describe())
# Out:
#     Age  Rating  PinCode
# 0    25    4.23      100
# 1    26    3.24      200
# 2    25    3.98      100
# 3    23    2.56      300
# 4    30    3.20      500
# 5    29    4.60      600
# 6    23    3.80      700
# 7    34    3.78      800
# 8    40    2.98      900
# 9    30    4.80      110
# 10   51    4.10      111
# 11   46    3.65      112
# ####### Sum ######
# Age         382.00
# Rating       44.92
# PinCode    4533.00
# dtype: float64
# ###### Mean ######
# Age         31.833333
# Rating       3.743333
# PinCode    377.750000
# dtype: float64
# ###### Standard Deviation ######
# Age          9.232682
# Rating       0.661628
# PinCode    305.201014
# dtype: float64
# ###### Descriptive Statistics ######
#              Age     Rating     PinCode
# count  12.000000  12.000000   12.000000
# mean   31.833333   3.743333  377.750000
# std     9.232682   0.661628  305.201014
# min    23.000000   2.560000  100.000000
# 25%    25.000000   3.230000  110.750000
# 50%    29.500000   3.790000  250.000000
# 75%    35.500000   4.132500  625.000000
# max    51.000000   4.800000  900.000000
